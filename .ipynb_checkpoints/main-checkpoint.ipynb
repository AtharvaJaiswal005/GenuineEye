# %% [markdown]
# # GenuineEye: RealFake Classifer

# %% [markdown]
# # 1. Setting up Environment

# %%
import tensorflow as tf
import os

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
import cv2
import imghdr
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16620\4232469594.py:2: DeprecationWarning: 'imghdr' is deprecated and slated for removal in Python 3.13
#   import imghdr

# %%
data_dir = 'data'

# %%
image_exts = ['jpeg','jpg', 'bmp', 'png']

# %% [markdown]
# # 3. Loading Dataset

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = tf.keras.utils.image_dataset_from_directory('data')
# Out:
# Found 100000 files belonging to 2 classes.

# %%
data
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# # 4. Upscaleing Data

# %%
data = data.map(lambda x,y: (x/255, y))

# %%
data.as_numpy_iterator().next()
# Out:
# (array([[[[0.49803922, 0.6901961 , 0.6039216 ],
#           [0.49803922, 0.6901961 , 0.6039216 ],
#           [0.49803922, 0.6901961 , 0.6039216 ],
#           ...,
#           [0.34901962, 0.4745098 , 0.32941177],
#           [0.34901962, 0.4745098 , 0.32941177],
#           [0.34901962, 0.4745098 , 0.32941177]],
#
#          [[0.49803922, 0.6901961 , 0.6039216 ],
#           [0.49803922, 0.6901961 , 0.6039216 ],
#           [0.49803922, 0.6901961 , 0.6039216 ],
#           ...,
#           [0.34901962, 0.4745098 , 0.32941177],
#           [0.34901962, 0.4745098 , 0.32941177],
#           [0.34901962, 0.4745098 , 0.32941177]],
#
#          [[0.49803922, 0.6901961 , 0.6039216 ],
#           [0.49803922, 0.6901961 , 0.6039216 ],
#           [0.49803922, 0.6901961 , 0.6039216 ],
#           ...,
#           [0.34901962, 0.4745098 , 0.32941177],
#           [0.34901962, 0.4745098 , 0.32941177],
#           [0.34901962, 0.4745098 , 0.32941177]],
#
#          ...,
#
# ...

# %% [markdown]
# # 5. Spliting Data

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)

# %%
train_size
# Out:
# 2187

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# # 6. Building sequential CNN Deep Learning Model

# %%
train
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# C:\Users\Dell\.virtualenvs\GenuineEye-aUEcstyu\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 254, 254, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 127, 127, 16)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 125, 125, 32)        │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 62, 62, 32)          │               0 │
# ...

# %% [markdown]
# # 7. Training Dataset

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 2187/2187 ━━━━━━━━━━━━━━━━━━━━ 1303s 594ms/step - accuracy: 0.7665 - loss: 0.4636 - val_accuracy: 0.8904 - val_loss: 0.2655
# Epoch 2/20
# 2187/2187 ━━━━━━━━━━━━━━━━━━━━ 1052s 481ms/step - accuracy: 0.8941 - loss: 0.2619 - val_accuracy: 0.9051 - val_loss: 0.2316
# Epoch 3/20
# 2187/2187 ━━━━━━━━━━━━━━━━━━━━ 1056s 483ms/step - accuracy: 0.9202 - loss: 0.1971 - val_accuracy: 0.9143 - val_loss: 0.2175
# Epoch 4/20
# 2187/2187 ━━━━━━━━━━━━━━━━━━━━ 1113s 488ms/step - accuracy: 0.9405 - loss: 0.1498 - val_accuracy: 0.9145 - val_loss: 0.2329
# Epoch 5/20
# 2187/2187 ━━━━━━━━━━━━━━━━━━━━ 1093s 483ms/step - accuracy: 0.9578 - loss: 0.1076 - val_accuracy: 0.9194 - val_loss: 0.2389
# Epoch 6/20
# 2187/2187 ━━━━━━━━━━━━━━━━━━━━ 1090s 498ms/step - accuracy: 0.9728 - loss: 0.0763 - val_accuracy: 0.9216 - val_loss: 0.2630
# Epoch 7/20
# 2187/2187 ━━━━━━━━━━━━━━━━━━━━ 1056s 483ms/step - accuracy: 0.9808 - loss: 0.0539 - val_accuracy: 0.9200 - val_loss: 0.3034
# Epoch 8/20
# ...

# %% [markdown]
# # 8.Performance Evaluation

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # 9. Metric Evaluation

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# ...

# %%
print(pre.result(), re.result(), acc.result())
# Out:
# tf.Tensor(0.89160043, shape=(), dtype=float32) tf.Tensor(0.9479083, shape=(), dtype=float32) tf.Tensor(0.9166667, shape=(), dtype=float32)

# %% [markdown]
# # 10. Testing with custom image

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# Read the image using OpenCV
img = cv2.imread('samplefaketest.jpg')

# Convert from BGR to RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(img_rgb)
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step

# %%
yhat
# Out:
# array([[0.00020541]], dtype=float32)

# %%
if yhat > 0.5: 
    print(f'Predicted class is REAL')
else:
    print(f'Predicted class is Fake')
# Out:
# Predicted class is Fake

# %% [markdown]
# # 11. Saveing the Model for future use or deployment

# %%
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('models','genuine_eye_realorfake_imageclassifier.h5'))
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
new_model = load_model('./models/genuine_eye_realorfake_imageclassifier.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# #  Evalustion

# %%
# Check the model summary
from keras.models import Sequential
from keras.layers import Flatten, Dense, Conv2D, MaxPooling2D

# Example model
model = Sequential()

# Convolutional layers
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten before dense layers
model.add(Flatten())

# Dense layers
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # For binary classification

# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

new_model.summary()
# Out:
# C:\Users\Dell\.virtualenvs\GenuineEye-aUEcstyu\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 254, 254, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 127, 127, 16)        │               0 │
# ...

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import load_model
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report
import numpy as np

# Load the pre-trained model
new_model = load_model('./models/genuine_eye_realorfake_imageclassifier.h5')

# Create a data generator for your test set
test_datagen = ImageDataGenerator(rescale=1./255)

# Load test images from the directory and resize them to match the model's expected input size
test_generator = test_datagen.flow_from_directory(
    './test',   # Path to the folder containing 'real' and 'fake' subfolders
    target_size=(254, 254),  # Adjust this to the input size expected by the model
    batch_size=32,
    class_mode='binary',
    shuffle=False
)

# Get the ground truth labels from the test generator
y_true = test_generator.classes

# Predict using the model
y_pred = new_model.predict(test_generator)
y_pred = np.round(y_pred).astype(int)  # Round to the nearest integer

# Calculate evaluation metrics
conf_matrix = confusion_matrix(y_true, y_pred)
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)
classification_rep = classification_report(y_true, y_pred)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Found 20000 images belonging to 2 classes.
# C:\Users\Dell\.virtualenvs\GenuineEye-aUEcstyu\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 142s 227ms/step

# %%
print("Confusion Matrix:")
print(conf_matrix)
print("\nAccuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("\nClassification Report:")
print(classification_rep)
# Out:
# Confusion Matrix:
# [[9977   23]
#  [7632 2368]]
#
# Accuracy: 0.61725
# Precision: 0.9903805938937683
# Recall: 0.2368
# F1 Score: 0.382212896457106
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.72     10000
#            1       0.99      0.24      0.38     10000
#
#     accuracy                           0.62     20000
#    macro avg       0.78      0.62      0.55     20000
# weighted avg       0.78      0.62      0.55     20000
